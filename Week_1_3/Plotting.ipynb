# %% [markdown]
# # Problem 1
# Plot a scatter plot of Data using the first column as x and the first column as y, using red points.

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#input
x=np.random.randn(15)
Data=np.hstack([x[:,None],x[:,None]])
print(Data)
# Out:
# [[-0.52009103 -0.52009103]
#  [-1.85366619 -1.85366619]
#  [ 0.43119302  0.43119302]
#  [ 1.38283287  1.38283287]
#  [ 0.77071322  0.77071322]
#  [-1.80067505 -1.80067505]
#  [ 0.49561215  0.49561215]
#  [ 0.21152891  0.21152891]
#  [-0.91245848 -0.91245848]
#  [ 0.11574765  0.11574765]
#  [-0.53104733 -0.53104733]
#  [-0.12836805 -0.12836805]
#  [-0.27267637 -0.27267637]
#  [ 1.0355933   1.0355933 ]
#  [-0.47675931 -0.47675931]]

# %%
#Solution of #1
plt.xlabel("X-axis", fontsize=18)
plt.ylabel("Y-axis", fontsize=20)
plt.scatter(Data[:,0], Data[:,1], color='r')

# %% [markdown]
# # Problem 2
# Plot a scatter plot of Data using the first column as x and the first column as y,
# and add the label "x" and "y" to the respective columns using `fontsize` 14.

# %%
#solution
plt.xlabel("X", fontsize=14)
plt.ylabel("Y", fontsize=14)
plt.scatter(Data[:,0], Data[:, 0])

# %% [markdown]
# # Problem 4
# Plot the graph of the function $\cos(8 x)$ for $x \in[0,1]$ and add the label "x" and "cos(8x)" to the respective columns using `fontsize` 14.

# %%
x = np.linspace(0, 1, 100)
y = np.cos(8 * x)
plt.xlabel("x", fontsize=14)
plt.ylabel("cos(8x)", fontsize=14)
plt.plot(x, y)

# %% [markdown]
# # Problem 5
# Plot the histogram of Data using 30 bins.

# %%
#input
Data=np.random.randn(2000)

# %%
plt.hist(Data, bins=30)
# Out:
# (array([  3.,   2.,   2.,  11.,  13.,  25.,  36.,  59., 100., 103., 134.,
#         173., 185., 182., 172., 202., 137., 135., 106.,  81.,  56.,  35.,
#          17.,   8.,  10.,   6.,   2.,   1.,   2.,   2.]),
#  array([-3.41988826, -3.17337331, -2.92685836, -2.68034341, -2.43382847,
#         -2.18731352, -1.94079857, -1.69428362, -1.44776868, -1.20125373,
#         -0.95473878, -0.70822383, -0.46170889, -0.21519394,  0.03132101,
#          0.27783596,  0.5243509 ,  0.77086585,  1.0173808 ,  1.26389575,
#          1.51041069,  1.75692564,  2.00344059,  2.24995554,  2.49647048,
#          2.74298543,  2.98950038,  3.23601533,  3.48253027,  3.72904522,
#          3.97556017]),
#  <BarContainer object of 30 artists>)

# %% [markdown]
# # Problem 6
# Bar plot of x and money below

# %%
#input
x = np.arange(4)
money = [1.5e5, 2.5e6, 5.5e6, 2.0e7]

# %%
plt.bar(x, money)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# # Problem 7
# Plot the graph of the function $\cos(8 x)$ in red and $x^2$ in blue for $x \in[0,1]$ and add the label "x" and "f(x)" to the respective columns using `fontsize` 14.

# %%
x = np.linspace(0, 1, 50)
y = np.cos(8*x)
plt.xlabel("x", fontsize=14)
plt.ylabel("f(x)", fontsize=14)
plt.plot(x, y, color="r")
plt.plot(x, np.square(x), color="b")

# %% [markdown]
# # Problem 8
# Plot the graph of the function $\cos(8 x)$ in red and $x^2$ in blue for $x \in[0,1]$ and add a legend
# with labels "cos(8x)" and "$x^2$"

# %%
x = np.linspace(0, 1, 50)
y = np.cos(8*x)
plt.xlabel("x", fontsize=14)
plt.ylabel("f(x)", fontsize=14)
plt.plot(x, y, label="cos(8x)", color="r")
plt.plot(x, np.square(x), label="$x^2$", color="b")
plt.legend()

# %% [markdown]
# # Problem 9
# Save the previous plot in png format

# %%
x = np.linspace(0, 1, 50)
y = np.cos(8*x)
plt.xlabel("x", fontsize=14)
plt.ylabel("f(x)", fontsize=14)
plt.plot(x, y, label="cos(8x)", color="r")
plt.plot(x, np.square(x), label="$x^2$", color="b")
plt.legend()
plt.savefig("pr9.png")

# %% [markdown]
# # Problem 10
# Plot the box plot of data

# %%
#input
Data=np.random.laplace(0,2,100)

# %%
plt.boxplot(Data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fa18d3b7580>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fa18d3b7c40>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fa18d3b7220>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fa18d3be340>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fa18d3be6a0>],
#  'means': []}

# %% [markdown]
# # Problem 11
# Plot the graph of the 2D function $e^{-x^2-y^2}$  for $x,y \in[-3,3]$.

# %%
x = np.arange(-3.0, 3.0, 0.05)
y = np.arange(-3.0, 3.0, 0.05)
X, Y = np.meshgrid(x, y)
Z = np.exp(-X**2 - Y**2)
fig, ax = plt.subplots()
CS = ax.contour(X, Y, Z)
